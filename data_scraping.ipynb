# %%
from bs4 import BeautifulSoup as b4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import csv
import cv2

# %%
URL = "https://en.wikipedia.org/wiki/List_of_Indian_dishes"
#print(page.text)

'''
for i in range(0, 1261, 30):
        try:
            headers = {
                'user-agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.111 Safari/537.36',
            }
            response = requests.get("https://www.tripadvisor.in/Hotels-g297604-oa"+str(i)+"-Goa-Hotels.html", headers=headers, timeout=5)

            if response.status_code != 200:
                print("error!")
            else:
                print(response.status_code)
        except requests.exceptions.Timeout as error:
            print('time out')
'''   
table_class="wikitable sortable north jquery-tablesorter"
response=requests.get(URL)
print(response.status_code)

soup = b4(response.text, 'html.parser')
t=soup.find('table',{'class':"wikitable sortable"})
nt=soup.find('table',{'class':"wikitable sortable north"})
st=soup.find('table',{'class':"wikitable sortable south"})
wt=soup.find('table',{'class':"wikitable sortable west"})
et=soup.find('table',{'class':"wikitable sortable east"})

ind = pd.read_html(str(t))
inddf = pd.DataFrame(ind[0])

nind = pd.read_html(str(nt))
ninddf = pd.DataFrame(nind[0])

sind = pd.read_html(str(st))
sinddf = pd.DataFrame(sind[0])

wind = pd.read_html(str(wt))
winddf = pd.DataFrame(wind[0])

eind = pd.read_html(str(et))
einddf = pd.DataFrame(eind[0])

data = [inddf, ninddf, sinddf, winddf, einddf]

df = pd.concat(data)

#df.columns
df = df.drop(["Dish Type", "Image"], axis=1)
df.columns
df.index = [i for i in range(1,327)]
df
# Out:
# 200
#                Name                                        Description  \
# 1        Maach Jhol  Fish with potol, tomato, chillies, ginger and ...
# 2       Pork Bharta  Boiled pork with onions, chillies, ginger and ...
# 3    Chak-Hao Kheer                  Purple rice porridge from Manipur
# 4             Galho  Galho is similar to khichdi, a dish made from ...
# 5    Achari baingan         brinjal cooked with pickle spices in gravy
# ..              ...                                                ...
# 322        Shondesh  A dessert with milk and sugar. A signature Ben...
# 323          Shukto  A Bengali cuisine. Diced potatoes, sweet potat...
# 324      Sunga Pork                              Rich spicy pork curry
# 325       Tenga Doi                                          Sour curd
# 326       Til Pitha  A sweet Assamese specialty. Rice powder, til, ...
#
#     Vegetarian/Non-Vegetarian
# 1           Non-Vegetarian[1]
# 2           Non-Vegetarian[1]
# ...

# %%
df.to_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/5k/__r1tsvd7r77tn23ncdb22c40000gn/T/ipykernel_3321/916314944.py in <module>
# ----> 1 df.to_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx",index=False)
#
# NameError: name 'df' is not defined

# %%
pip install Google-Images-Search
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 865.8/865.8 kB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 11.1 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.8/96.8 kB 3.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.3/120.3 kB 3.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 218.0/218.0 kB 4.7 MB/s eta 0:00:0000:01
# ...
#   Created wheel for termcolor: filename=termcolor-1.1.0-py3-none-any.whl size=4832 sha256=3e69ee2ef2eb63a108d1b02210b06f9105c689e6a77425a2d4355bc2426fedbd
#   Stored in directory: /Users/jangayarkanni/Library/Caches/pip/wheels/b6/0d/90/0d1bbd99855f99cb2f6c2e5ff96f8023fad8ec367695f7d72d
# Successfully built termcolor
# ...
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 2.1.1
#     Uninstalling termcolor-2.1.1:
#       Successfully uninstalled termcolor-2.1.1
# ...

# %%
pip install google_images_download
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 9.6 MB/s eta 0:00:00:00:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 384.9/384.9 kB 6.6 MB/s eta 0:00:0000:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 1.8 MB/s eta 0:00:00
# ...
#   Created wheel for google_images_download: filename=google_images_download-2.8.0-py2.py3-none-any.whl size=14532 sha256=1e639ac0da1e306fd6106d3b534ee3226fe9f186d8ca9a1e9108f6d77d9653b6
#   Stored in directory: /Users/jangayarkanni/Library/Caches/pip/wheels/49/5e/9d/6a5de7d848f2a567fb2d65da3bd5fd986158934fbc70c8e7a7
# Successfully built google_images_download
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_images_search import GoogleImagesSearch
gis = GoogleImagesSearch('AIzaSyDu4MlCLXK4D8N7BRm2IjuO0lFcDYml9P8', '46a8508e8b3c645d4')
gsearch_params= ["thank you slide black background"]


from google_images_download import google_images_download

response = google_images_download.googleimagesdownload()
query = 'The smartphone also features an in display fingerprint sensor.'

arg = {"keywords":query}

try:
    response.download(arg)
except FileNotFoundError:
        arguments = {"keywords": query}
                      
        try:
            response.download(arguments)
        except:
            pass
# Out:
# Item no.: 1 --> Item name = The smartphone also features an in display fingerprint sensor.
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 100 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0

# %%
# importing google_images_download module
from google_images_download import google_images_download

# creating object
response = google_images_download.googleimagesdownload()

search_queries = [
	
'The smartphone also features an in display fingerprint sensor.',
'The pop up selfie camera is placed aligning with the rear cameras.',
'''In terms of storage Vivo V15 Pro could offer
up to 6GB of RAM and 128GB of onboard storage.''',
'The smartphone could be fuelled by a 3 700mAh battery.',
]


def downloadimages(query):
	# keywords is the search query
	# format is the image file format
	# limit is the number of images to be downloaded
	# print urls is to print the image file url
	# size is the image size which can
	# be specified manually ("large, medium, icon")
	# aspect ratio denotes the height width ratio
	# of images to download. ("tall, square, wide, panoramic")
	arguments = {"keywords": query,
				"format": "jpg",
				"limit":4,
				"print_urls":True,
				"size": "medium",
                "usage_rights": "labeled-for-reuse",
				"aspect_ratio":"panoramic"}
	try:
		response.download(arguments)
	
	# Handling File NotFound Error
	except FileNotFoundError:
		arguments = {"keywords": query,
					"format": "jpg",
					"limit":4,
					"print_urls":True,
					"size": "medium"}
					
		# Providing arguments for the searched query
		try:
			# Downloading the photos based
			# on the given arguments
			response.download(arguments)
		except:
			pass

# Driver Code
for query in search_queries:
	downloadimages(query)
	print()
# Out:
# Item no.: 1 --> Item name = The smartphone also features an in display fingerprint sensor.
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 4 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = The pop up selfie camera is placed aligning with the rear cameras.
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 4 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = In terms of storage Vivo V15 Pro could offer
# up to 6GB of RAM and 128GB of onboard storage.
# Evaluating...
# Starting Download...
#
#
# Unfortunately all 4 could not be downloaded because some images were not downloadable. 0 is all we got for this search filter!
#
# Errors: 0
#
#
#
# Item no.: 1 --> Item name = The smartphone could be fuelled by a 3 700mAh battery.
# Evaluating...
# ...

# %%
import urllib.request
from bs4 import BeautifulSoup as b4
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests
import csv
import cv2
import os
def get_img(quer):
    im = "https://www.google.com/search?q="+quer+"&hl=en&authuser=0&tbm=isch&sxsrf=ALiCzsY92VOIq1NKz-LpP8aLGDn9tKAaZg%3A1670916527836&source=hp&biw=1440&bih=684&ei=rymYY_jNMO2F4t4PvuyF6As&iflsig=AJiK0e8AAAAAY5g3v-udnPDV400p02Oufkcyd4kyn1p2&oq=&gs_lcp=CgNpbWcQARgAMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnUABYAGDFEGgBcAB4AIABAIgBAJIBAJgBAKoBC2d3cy13aXotaW1nsAEK&sclient=img"
    pa=requests.get(im)
    print(pa.status_code)
    paa = b4(pa.content, 'html.parser')
    da = paa.find_all('img',{'class':"yWs4tf"})
    links = []
    for i in da:
        links.append(i['src'])
    count = 1
    dirn = "/Users/jangayarkanni/Desktop/GAIP/Note_book/"+quer+"_dats"
    os.mkdir(dirn)
    for i in range(len(links)):
        re = urllib.request.urlopen(links[i])
        arr = np.asarray(bytearray(re.read()), dtype=np.uint8)
        ima = cv2.imdecode(arr, cv2.IMREAD_COLOR)
        cv2.imwrite(os.path.join(dirn,quer+"_"+str(count)+".jpg"), ima)
        cv2.imwrite(quer+"/"+quer+"_"+str(count)+".jpg", ima)
        count+=1
'''
df = pd.read_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx")
dfv = df[df['Vegetarian/Non-Vegetarian']=="Non-Vegetarian"]
lis = list(dfv['Name'])
val = list()
for j in range(len(lis)):
    print(lis[j])
    val.append('_'.join(lis[j].split()))
for i in range(len(lis)):
    get_img(val[i])

'''
# Out:
# '\ndf = pd.read_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx")\ndfv = df[df[\'Vegetarian/Non-Vegetarian\']=="Non-Vegetarian"]\nlis = list(dfv[\'Name\'])\nval = list()\nfor j in range(len(lis)):\n    print(lis[j])\n    val.append(\'_\'.join(lis[j].split()))\nfor i in range(len(lis)):\n    get_img(val[i])\n\n'

# %% [markdown]
# df = pd.read_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx")
# dfv = df[df['Vegetarian/Non-Vegetarian']=="Non-Vegetarian"]
# lis = list(dfv['Name'])
# val = list()
# for j in range(len(lis)):
#     print(lis[j])
#     val.append('_'.join(lis[j].split()))
# for i in range(len(lis)):
#     get_img(val[i])

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install opencv-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 MB 9.3 MB/s eta 0:00:00:00:0100:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df = pd.read_excel("/Users/jangayarkanni/Desktop/GAIP/food.xlsx")

# %%
dfv = df[df['Vegetarian/Non-Vegetarian']=="Non-Vegetarian"]

# %%
dfv.index=[i for i in range(len(list(dfv.index)))]
dfv
# Out:
#                  Name                                        Description  \
# 0      Amritsari fish     Fried fish made with curry, ginger, and garlic
# 1             Biryani  Mixed rice dish, optional spices, optional veg...
# 2      Butter chicken  dish, originating in the Indian subcontinent, ...
# 3      Murgh musallam                                                NaN
# 4    Tandoori Chicken  Tandoori chicken as a dish originated in the P...
# 5  Chettinadu Chicken                       Dish made chicken and spices
# 6          Chicken 65  Popular deep fried chicken preparation. Chicke...
# 7      Nandu omelette         an omelette with pieces of crab and spices
# 8          Bombil fry                   Main Course; Bombay Duck (Fish).
#
#   Vegetarian/Non-Vegetarian
# 0            Non-Vegetarian
# 1            Non-Vegetarian
# 2            Non-Vegetarian
# 3            Non-Vegetarian
# 4            Non-Vegetarian
# 5            Non-Vegetarian
# 6            Non-Vegetarian
# ...

# %%
lis = list(dfv['Name'])

# %%
val = list()
for j in range(len(lis)):
    print(lis[j])
    val.append('_'.join(lis[j].split()))
# Out:
# Amritsari fish
# Biryani
# Butter chicken
# Murgh musallam
# Tandoori Chicken
# Chettinadu Chicken
# Chicken 65
# Nandu omelette
# Bombil fry

# %%
val
# Out:
# ['Amritsari_fish',
#  'Biryani',
#  'Butter_chicken',
#  'Murgh_musallam',
#  'Tandoori_Chicken',
#  'Chettinadu_Chicken',
#  'Chicken_65',
#  'Nandu_omelette',
#  'Bombil_fry']

# %%
for i in range(len(lis)):
    get_img(val[i])
# Out:
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
im = "https://www.google.com/search?q="+"Biriyani"+"&hl=en&authuser=0&tbm=isch&sxsrf=ALiCzsY92VOIq1NKz-LpP8aLGDn9tKAaZg%3A1670916527836&source=hp&biw=1440&bih=684&ei=rymYY_jNMO2F4t4PvuyF6As&iflsig=AJiK0e8AAAAAY5g3v-udnPDV400p02Oufkcyd4kyn1p2&oq=&gs_lcp=CgNpbWcQARgAMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnMgcIIxDqAhAnUABYAGDFEGgBcAB4AIABAIgBAJIBAJgBAKoBC2d3cy13aXotaW1nsAEK&sclient=img"
pa=requests.get(im)
print(pa.status_code)
paa = b4(pa.content, 'html.parser')
da = paa.find_all('img',{'class':"yWs4tf"})
links = []
for i in da:
    links.append(i['src'])
count = 1
import urllib.request
#for i in range(len(links)):
re = urllib.request.urlopen(links[0])
arr = np.asarray(bytearray(re.read()), dtype=np.uint8)
ima = cv2.imdecode(arr, cv2.IMREAD_COLOR)
dirn = "/Users/jangayarkanni/Desktop/GAIP/Note_book/Biriyani_dats"
os.mkdir(dirn)
cv2.imwrite(os.path.join(dirn,"Biriyani"+"_"+str(count)+".jpg"), ima)
count+=1
# Out:
# 200

# %%
get_img("no")
# Out:
# 200

# %%
paa.find_all('img')
# Out:
# [<img alt="Google" class="kgJEQe" src="/images/branding/searchlogo/1x/googlelogo_desk_heirloom_color_150x55dp.gif"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQpOBjCPrQ6oBzolat7OL3sjs2WRRqKcgLulj-cqY42y5M2IYGe9M0VYSRbNA&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRRfLyx1CX8wb815MOWJSjziUoHyKg6mpTVocVVeN4OsyWpgd2hm75NbwxrFw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQG_o9psvNw2uyywNYE9Bzog3a0E60dRTzVqsXeanx9xUVMgxxOGwrMKsPIaQ&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTxrDGUhYeUUGG5NUl4Y63fKKT0lAD2fp5BdlHzFObVpYZVVRaLo60ze-ceMw&amp;s"/>,
#  <img alt="" class="yWs4tf" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTDEtquJO8VYEb68JI9guK3eO-b2iCkarz4xnpdjDFErDwmnTjHWNY_rgCwS4o&amp;s"/>,
# ...

# %%
im1 = "https://www.google.com/search?q=Biryani&tbm=isch&ved=2ahUKEwia49X7k_f7AhUnwnMBHUSlCIQQ2-cCegQIABAA&oq=Biryani&gs_lcp=CgNpbWcQAzIHCAAQsQMQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQzIECAAQQ1AAWABglgZoAHAAeACAASyIASySAQExmAEAqgELZ3dzLXdpei1pbWfAAQE&sclient=img&ei=RLuYY5qxDKeEz7sPxMqioAg&authuser=0&bih=684&biw=1440&hl=en" 
pa1=requests.get(im1)
print(pa1.status_code)
paa1 = b4(pa1.text, 'html.parser')
da1= paa1.findAll('img',{'class':"yWs4tf"})
links1 = []
for i in da1:
    links1.append(i['src'])
# Out:
# 200

# %%
paa1.prettify
# Out:
# <bound method Tag.prettify of <!DOCTYPE html PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.0//EN" "http://www.wapforum.org/DTD/xhtml-mobile10.dtd">
# ...

# %%
paa1.content

# %%
infinity scrolling ------- 20 images only issue
# Out:
#   File "/var/folders/5k/__r1tsvd7r77tn23ncdb22c40000gn/T/ipykernel_6035/3601447187.py", line 1
#     infinity scrolling ------- 20 images only issue
#              ^
# SyntaxError: invalid syntax

# %%
from serpapi import GoogleSearch
import os, json

image_results = []
params = {
  "q": "Naan",
  "hl": "en",
    "tbm": "isch",                    
    "num": "100",                     
    "ijn": 0,
  "gl": "us",
  "domain": "images.google.com",
  "api_key": "6650fe080913c649746126a3d53cb4079e8b3248a76de2ce34a33433ba0418cf"
}
    
search = GoogleSearch(params)         
    
images_is_present = True
while images_is_present:
    results = search.get_dict()       
    if "error" not in results:
        for image in results["images_results"]:
            if image["thumbnail"] not in image_results:
                    image_results.append(image["original"])
                
# update to
        params["ijn"] += 1
    else:
        images_is_present = False
        print(results["error"])

print(json.dumps(image_results, indent=2))
# Out:
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# https://serpapi.com/search
# Google hasn't returned any results for this query.
# [
#   "https://rasamalaysia.com/wp-content/uploads/2019/03/naan-thumb.jpg",
#   "https://www.budgetbytes.com/wp-content/uploads/2010/09/Homemade-Naan-stack-1.jpg",
#   "https://assets.epicurious.com/photos/62069cd50297ea306174e51d/1:1/w_4294,h_4294,c_limit/Naan_RECIPE_021022_27679.jpg",
#   "https://www.kingarthurbaking.com/sites/default/files/2021-02/naan-3.jpg",
#   "https://www.thespruceeats.com/thmb/MReCj8olqrCsPaGvikesPJie02U=/1500x0/filters:no_upscale():max_bytes(150000):strip_icc()/naan-leavened-indian-flatbread-1957348-final-08-116a2e523f6e4ee693b1a9655784d9b9.jpg",
#   "https://arbuz.com/wp-content/uploads/2019/04/Easy-Naan-Recipe.jpg",
# ...

# %%
pip install google-search-results
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for google-search-results: filename=google_search_results-2.4.1-py3-none-any.whl size=25775 sha256=98d6c4ee0b1073593a3ad942c4565d4824bdbf1181fb98c9bcf1b5612e6c81a8
#   Stored in directory: /Users/jangayarkanni/Library/Caches/pip/wheels/e2/a8/8f/2c80a580d272be8f2088340d2c2b152c51077e01d6281beaef
# Successfully built google-search-results
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
image
# Out:
# {'position': 578,
#  'original': 'https://www.tarladalal.com/collections/popular-indian-bread-naan-recipes.jpg',
#  'original_width': 696,
#  'original_height': 1000,
#  'source': 'www.tarladalal.com',
#  'title': '10 Popular Indian Naan Recipes | TarlaDalal.com',
#  'link': 'https://www.tarladalal.com/article-10-popular-indian-naan-recipes-59',
#  'thumbnail': 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTg-yz0RBadN8re_sYnhot9ZcrPTTSIom64sIZDA7oN-m5_yK5z&s'}

# %%
cv2.imread(image_results[0])
# Out:
# [ WARN:0@6982.287] global /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgcodecs/src/loadsave.cpp (239) findDecoder imread_('https://rasamalaysia.com/wp-content/uploads/2019/03/naan-thumb.jpg'): can't open/read file: check file path/integrity

# %%
for i in range(1,25):
    try:
        re1 = urllib.request.urlopen(image_results[i-1])
        arr = np.asarray(bytearray(re1.read()), dtype=np.uint8)
        ima = cv2.imdecode(arr, cv2.IMREAD_COLOR)
        plt.subplot(10, 10, i, )
        plt.title(i)
        plt.axis("off")
        plt.imshow(ima)
    except urllib.request.HTTPError:
        pass
